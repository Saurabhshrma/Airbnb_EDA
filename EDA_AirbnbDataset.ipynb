# %% [markdown]
# # **Project Name**    - AirBnb booking analysis

# %% [markdown]
# ##### **Project Type**     - EDA
# ##### **Contribution**    - Individual
# ##### **Team Member**  - Saurabh Sharma

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The data provided contains information on listings for rentals on the Airbnb platform. There are a total of 48895 rows in the data, with 16 columns including the price of the listing, the number of reviews the listing has received, the neighborhood the listing is located in, and the room type.
#
# Upon further exploration, it appears that the data is not evenly distributed among the various columns. For example, the majority of listings are located in the Manhattan neighborhood, with Private room,Entire home/apt being the most common room type.
#
# When analyzing the price of the listings, it becomes clear that the price of the listings varies greatly, with a minimum price of  0 dollar and a maximum price of dollar 10,000. The average price of a listing is  152 dollar , while the standard deviation is  240, indicating that there is a significant amount of variance in the price of the listings. The most common room type is Entire home/apt, with 25,409 listings falling under this category.
# Minimum nights for that user must have to book is majorly 1 or 2.
#
# One interesting insight that can be gleaned from the data is the relationship between the number of reviews a listing has received and its price. Upon creating a scatterplot and seeing coorelation of these two variables, it becomes clear that there is a slight negative correlation between the number of reviews and the price of a listing, with listings that have received more reviews tending to have slighltly lower prices. This could potentially be due to the fact that listings with a higher number of reviews are likely to be more popular and because of cheaper price, leading to an decrease in price.This means that, on average, listings with more reviews tend to be priced lesser.
#
# Another important factor that could impact the price of a listing is the neighborhood in which it is located. Upon creating a bar chart to visualize the average price of listings in each neighborhood group, it becomes clear that the neighborhoods of Manhattan and Brooklyn have the highest average prices, while Queens and the Bronx have the lowest. This could be due to the popularity and desirability of these areas, as well as potentially higher demand for rentals in these neighborhoods.
#
# Availability of property also plays important role , can be seen in linear statistics that we perform , it effect price positively.
#
# Additionally, the type of room appears to have an effect on the price. Private rooms and entire homes/apartments tend to be priced higher than shared rooms.We also see higher availablity of the room higher the price.
#
# Overall, the data suggests that location, room type,reviews,availability are important factors in determining the price of a listing on Airbnb. The number of reviews a listing has received also appears to have an effect on the price, with more popular listings tending to be priced lower.By analyzing various attributes of the listings such as price, number of reviews, and neighborhood,availability stakeholders can gain a better understanding of the rental market and make informed decisions about their listings.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Understanding the factors that influence the price of a listing. This information could be useful for both hosts, who want to price their listings competitively, and guests, who want to find affordable accommodations.**

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The business objective for the Airbnb dataset could be to understand the factors that influence the price of a listing and to identify opportunities for increasing the revenue of the business. This could involve analyzing the characteristics of the listings, such as the location, the type of room, and the amenities offered, as well as understanding the demand for the listings, as indicated by the number of reviews and the booking rate. By understanding these factors, the business could target its marketing efforts and pricing strategies more effectively and potentially increase the profitability of the listings on the platform.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
airbnb_df = pd.read_csv('Airbnb NYC 2019.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
airbnb_df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
airbnb_df.shape
# Out:
# (48895, 16)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
airbnb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
#counting the number of duplicates in every column
# df.count() give non null values and df.nunique() give unique values in column

for i in airbnb_df:
    print(i,':',airbnb_df[i].count() - airbnb_df[i].nunique())
# Out:
# id : 0
# name : 974
# host_id : 11438
# host_name : 37422
# neighbourhood_group : 48890
# neighbourhood : 48674
# latitude : 29847
# longitude : 34177
# room_type : 48892
# price : 48221
# minimum_nights : 48786
# number_of_reviews : 48501
# last_review : 37079
# reviews_per_month : 37906
# calculated_host_listings_count : 48848
# availability_365 : 48529

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
null_counts = airbnb_df.isnull().sum()
null_counts
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# #### Unique values in every column

# %%
for i in airbnb_df:
    print(i,':',airbnb_df[i].nunique())
# Out:
# id : 48895
# name : 47905
# host_id : 37457
# host_name : 11452
# neighbourhood_group : 5
# neighbourhood : 221
# latitude : 19048
# longitude : 14718
# room_type : 3
# price : 674
# minimum_nights : 109
# number_of_reviews : 394
# last_review : 1764
# reviews_per_month : 937
# calculated_host_listings_count : 47
# availability_365 : 366

# %%
# Checking if the property with same name have same host
airbnb_df['name'].value_counts()
# Out:
# Hillside Hotel                                        18
# Home away from home                                   17
# New york Multi-unit building                          16
# Brooklyn Apartment                                    12
# Loft Suite @ The Box House Hotel                      11
#                                                       ..
# Large 1BR Apt. in Williamsburg                         1
# Feel at Home                                           1
# Spacious Modern Alcove Studio in a Luxury Building     1
# Artist's Room in Large Apartment                       1
# Trendy duplex in the very heart of Hell's Kitchen      1
# Name: name, Length: 47905, dtype: int64

# %%
airbnb_df[(airbnb_df['name']=='Hillside Hotel')]
# Out:
#              id            name    host_id       host_name  \
# 24152  19456810  Hillside Hotel  134184451  Hillside Hotel
# 24607  19785737  Hillside Hotel  134184451  Hillside Hotel
# 26734  21231543  Hillside Hotel  134184451  Hillside Hotel
# 26752  21243952  Hillside Hotel  134184451  Hillside Hotel
# 26753  21244035  Hillside Hotel  134184451  Hillside Hotel
# 26889  21311903  Hillside Hotel  134184451  Hillside Hotel
# 26891  21312075  Hillside Hotel  134184451  Hillside Hotel
# 26892  21312191  Hillside Hotel  134184451  Hillside Hotel
# 26893  21312225  Hillside Hotel  134184451  Hillside Hotel
# 26894  21312283  Hillside Hotel  134184451  Hillside Hotel
# 26895  21312330  Hillside Hotel  134184451  Hillside Hotel
# 26896  21312403  Hillside Hotel  134184451  Hillside Hotel
# 26897  21312440  Hillside Hotel  134184451  Hillside Hotel
# 26898  21312495  Hillside Hotel  134184451  Hillside Hotel
# 26899  21312549  Hillside Hotel  134184451  Hillside Hotel
# ...

# %%
airbnb_df[(airbnb_df['name']=='Private room')]
# Out:
#              id          name    host_id  host_name neighbourhood_group  \
# 5381    3888469  Private room    8834412    Deborah               Bronx
# 8416    6462549  Private room    3312204       Olga           Manhattan
# 13997  10659825  Private room   55060863        Rob            Brooklyn
# 25791  20638833  Private room  147567811    Renaldy              Queens
# 27526  21668647  Private room   22420999     Herman              Queens
# 29497  22637533  Private room   89320309      Rishi            Brooklyn
# 36432  28965273  Private room  154737520  Mehrangez            Brooklyn
# 39075  30511096  Private room  132784640      Karen            Brooklyn
# 39416  30728885  Private room    9412549    Michael           Manhattan
# 43960  33967503  Private room   10188543    Charvii              Queens
#
#             neighbourhood  latitude  longitude     room_type  price  \
# 5381             Longwood  40.81321  -73.90259  Private room    100
# ...

# %% [markdown]
# As can be seen , there can be multiple property with a specific 'name'

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Answer Here
#
# 1 - The data is a list of Airbnb listings in New York City. Each row represents a single listing, and the columns contain information about the listing such as the ID, name, host ID, host name, neighborhood group, neighborhood, latitude, longitude, room type, price, minimum number of nights, number of reviews, last review, reviews per month, calculated host listings count, and availability in days.
#
# 2 - There are 48895 rows and 16 columns out of which 10 contains numerical data and 6 contains categorical.
#
# 3 - 'name' and 'hostname' contains some null values. which we will not bother with.
#
# 4 - 'Host name' , and property 'name' aren't good columns to identify uniquely.they can be copied.
#
# 5 - To identify each listing uniquely we will use 'id' , and each host uniquely we will use 'host id'.
#
# 6 - last_review , reviews_per_month contains most null values.We have to treat null values here.
#
# 7 - There are 5 neighbourhood_group and 3 room_type.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
airbnb_df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
# Dataset Describe
airbnb_df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %% [markdown]
# ### Variables Description

# %% [raw]
# id                 : a unique identifier for each listing
# name               : the name of the listing
# host_id            : the unique identifier for the host of the listing
# host_name          : the name of the host
# neighbourhood_group: the name of the neighborhood the listing is located in
# neighbourhood      : the name of the specific neighborhood the listing is located in
# latitude           : the latitude coordinate for the location of the listing
# longitude          : the longitude coordinate for the location of the listing
# room_type          : the type of room offered (private room, entire home/apt, shared room)
# price              : the price per night for the listing
# minimum_nights     : the minimum number of nights a guest can stay at the listing
# number_of_reviews  : the number of reviews the listing has received
# last_review        : the date of the last review the listing received
# reviews_per_month  : the average number of reviews the listing receives per month
# calculated_host_listings_count: the number of listings the host has on the platform
# availability_365   : the number of days the listing is available for booking

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# We will choose to check unique values of some variables from whom we can derive some insights.
# but as we saw in unique column values aboce , only neighbourhood group , and room type will have feasible value_counts.
# for the rest selected we will see top values.

col = ['host_id','neighbourhood_group','neighbourhood','room_type','minimum_nights']

for i in col:
    print(i,':','counts')
    print(airbnb_df[i].value_counts())
    print('-------------------------------------------')
# Out:
# host_id : counts
# 219517861    327
# 107434423    232
# 30283594     121
# 137358866    103
# 16098958      96
#             ...
# 23727216       1
# 89211125       1
# 19928013       1
# 1017772        1
# 68119814       1
# Name: host_id, Length: 37457, dtype: int64
# -------------------------------------------
# neighbourhood_group : counts
# Manhattan        21661
# Brooklyn         20104
# Queens            5666
# Bronx             1091
# Staten Island      373
# Name: neighbourhood_group, dtype: int64
# -------------------------------------------
# neighbourhood : counts
# Williamsburg          3920
# Bedford-Stuyvesant    3714
# Harlem                2658
# Bushwick              2465
# Upper West Side       1971
#                       ...
# Fort Wadsworth           1
# Richmondtown             1
# New Dorp                 1
# Rossville                1
# Willowbrook              1
# Name: neighbourhood, Length: 221, dtype: int64
# -------------------------------------------
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %%
# First we will start with handling null values , Since they're 20% of data we cant remove all rows

# %%
# calculate the IQR of the 'price' column
q1 = df['price'].quantile(0.25)
q3 = df['price'].quantile(0.75)
iqr = q3 - q1

# define the threshold for outliers
threshold = 1.5 * iqr

# identify the outliers
outliers = df[(df['price'] < (q1 - threshold)) | (df['price'] > (q3 + threshold))]

# display the number of outliers
outliers
# Out:
#              id                                               name    host_id  \
# 61        15396                 Sunny & Spacious Chelsea Apartment      60278
# 85        19601                perfect for a family or small group      74303
# 103       23686  2000 SF 3br 2bath West Village private  townhouse      93790
# 114       26933  2 BR / 2 Bath Duplex Apt with patio! East Village      72062
# 121       27659                   3 Story Town House in Park Slope     119588
# ...         ...                                                ...        ...
# 48758  36420289    Rustic Garden House Apt, 2 stops from Manhattan   73211393
# 48833  36450896   Brand New 3-Bed Apt in the Best Location of FiDi   29741813
# 48839  36452721  Massage Spa. Stay overnight. Authors Artist dr...  274079964
# 48842  36453160  LUXURY MANHATTAN PENTHOUSE+HUDSON RIVER+EMPIRE...  224171371
# 48856  36457700  Large 3 bed, 2 bath , garden , bbq , all you need   66993395
#
# ...

# %%
# Group the data by room_type and calculate the mean and standard deviation of the price for each type
price_stats = df.groupby('neighbourhood_group')['price'].agg(['mean', 'std'])

# Extract the mean and standard deviation values
means = price_stats['mean']
stds = price_stats['std']

# Set the x-axis labels
n_types = ['Brooklyn', 'Queens', 'Manhattan', 'Staten Island', 'Bronx']
x_pos = range(len(n_types))

# Create the bar plot
fig, ax = plt.subplots()
ax.bar(x_pos, means, yerr=stds, align='center', alpha=0.5, ecolor='black', capsize=10)

# Set the x-axis labels
ax.set_xticks(x_pos)
ax.set_xticklabels(n_types)

# Add a title
plt.title('Price by Neighbourhood Group')

# Show the plot
plt.show()

# %%
# creating a copy of dataset
df = airbnb_df.copy()

# Convert the last_review column to datetime
df['last_review'] = pd.to_datetime(df['last_review'])

# filling null values to 0 if number_of reviews column is zero
df.loc[df['number_of_reviews'] == 0, ['reviews_per_month', 'last_review']] = 0
           
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
# Missing Values/Null Values Count
null_counts = df.isnull().sum()
null_counts
# Out:
# id                                 0
# name                              16
# host_id                            0
# host_name                         21
# neighbourhood_group                0
# neighbourhood                      0
# latitude                           0
# longitude                          0
# room_type                          0
# price                              0
# minimum_nights                     0
# number_of_reviews                  0
# last_review                        0
# reviews_per_month                  0
# calculated_host_listings_count     0
# availability_365                   0
# dtype: int64

# %%
#checking if there values less than 0 for price
df['price'].min()
# Out:
# 0

# %%
print('Average Price              ',' : ',df.price.mean())
print('Standard Deviation of Price',' : ',df.price.std())
# Out:
# Average Price                :  152.7206871868289
# Standard Deviation of Price  :  240.15416974718758

# %%
#Average room price
roomtype_stats = airbnb_df.groupby('room_type')['price'].agg(['min', 'max', 'mean'])
roomtype_stats = roomtype_stats.rename(columns={'min': 'min price', 'max': 'max price', 'mean': 'Average price'})

roomtype_stats
# Out:
#                  min price  max price  Average price
# room_type
# Entire home/apt          0      10000     211.794246
# Private room             0      10000      89.780973
# Shared room              0       1800      70.127586

# %%
#which area has most listings
hosts = airbnb_df.groupby('neighbourhood_group')['id'].nunique().reset_index()
hosts
# Out:
#   neighbourhood_group     id
# 0               Bronx   1091
# 1            Brooklyn  20104
# 2           Manhattan  21661
# 3              Queens   5666
# 4       Staten Island    373

# %%
#which area has most expensive property
neighbourhood_group_stats = airbnb_df.groupby('neighbourhood_group')['price'].agg(['min', 'max', 'mean'])
neighbourhood_group_stats = neighbourhood_group_stats.rename(columns={'min': 'min price', 'max': 'max price', 'mean': 'Average price'})

neighbourhood_group_stats
# Out:
#                      min price  max price  Average price
# neighbourhood_group
# Bronx                        0       2500      87.496792
# Brooklyn                     0      10000     124.383207
# Manhattan                    0      10000     196.875814
# Queens                      10      10000      99.517649
# Staten Island               13       5000     114.812332

# %%
#Count of tyoes of roomtype in different neighbourhood
df.groupby('neighbourhood_group')['room_type'].value_counts()
# Out:
# neighbourhood_group  room_type
# Bronx                Private room         652
#                      Entire home/apt      379
#                      Shared room           60
# Brooklyn             Private room       10132
#                      Entire home/apt     9559
#                      Shared room          413
# Manhattan            Entire home/apt    13199
#                      Private room        7982
#                      Shared room          480
# Queens               Private room        3372
#                      Entire home/apt     2096
#                      Shared room          198
# Staten Island        Private room         188
#                      Entire home/apt      176
#                      Shared room            9
# Name: room_type, dtype: int64

# %%
# proprty pricce by rooms
stats = airbnb_df.groupby(['neighbourhood_group', 'room_type'])['price'].agg(['min', 'max', 'mean']).reset_index()
stats
# Out:
#    neighbourhood_group        room_type  min    max        mean
# 0                Bronx  Entire home/apt   28   1000  127.506596
# 1                Bronx     Private room    0   2500   66.788344
# 2                Bronx      Shared room   20    800   59.800000
# 3             Brooklyn  Entire home/apt    0  10000  178.327545
# 4             Brooklyn     Private room    0   7500   76.500099
# 5             Brooklyn      Shared room    0    725   50.527845
# 6            Manhattan  Entire home/apt    0  10000  249.239109
# 7            Manhattan     Private room   10   9999  116.776622
# 8            Manhattan      Shared room   10   1000   88.977083
# 9               Queens  Entire home/apt   10   2600  147.050573
# 10              Queens     Private room   10  10000   71.762456
# 11              Queens      Shared room   11   1800   69.020202
# 12       Staten Island  Entire home/apt   48   5000  173.846591
# 13       Staten Island     Private room   20    300   62.292553
# ...

# %%
#Calculate the number of unique neighborhoods in each group
neighbourhood_stats = df.groupby('neighbourhood_group')['neighbourhood'].nunique().reset_index(name='unique_neighbourhoods')

#Calculate the average price in each group
neighbourhood_stats['average_price'] = df.groupby('neighbourhood_group')['price'].mean().reset_index(level=0)['price']

#Calculate the sum of reviews in each group
neighbourhood_stats['total_reviews'] = df.groupby('neighbourhood_group')['number_of_reviews'].sum().reset_index(level=0)['number_of_reviews']

neighbourhood_stats
# Out:
#   neighbourhood_group  unique_neighbourhoods  average_price  total_reviews
# 0               Bronx                     48      87.496792          28371
# 1            Brooklyn                     47     124.383207         486574
# 2           Manhattan                     32     196.875814         454569
# 3              Queens                     51      99.517649         156950
# 4       Staten Island                     43     114.812332          11541

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
# Finding the corelation

# Select the columns to use
X = df[['neighbourhood_group','reviews_per_month','room_type','minimum_nights','number_of_reviews','availability_365','price']]

# Convert the categorical columns to dummy variables
X = pd.get_dummies(X)

# Import the necessary libraries
from sklearn.preprocessing import StandardScaler

# Initialize a StandardScaler object
scaler = StandardScaler()
# Fit the scaler to the data
scaler.fit(X)
# Transform the data
X_normalized = scaler.transform(X)

#converting to dataframe
X_normalized_df = pd.DataFrame(X_normalized, columns=X.columns)
correlation = X_normalized_df.corr()

correlation
# Out:
#                                    reviews_per_month  minimum_nights  \
# reviews_per_month                           1.000000       -0.124905
# minimum_nights                             -0.124905        1.000000
# number_of_reviews                           0.589407       -0.080116
# availability_365                            0.163732        0.144303
# price                                      -0.050564        0.042799
# neighbourhood_group_Bronx                   0.036390       -0.018186
# neighbourhood_group_Brooklyn               -0.021512       -0.039658
# neighbourhood_group_Manhattan              -0.063723        0.067362
# neighbourhood_group_Queens                  0.107927       -0.032629
# neighbourhood_group_Staten Island           0.026648       -0.009400
# room_type_Entire home/apt                  -0.029565        0.074900
# room_type_Private room                      0.030178       -0.073837
# room_type_Shared room                      -0.001714       -0.004218
#
# ...

# %%
# Checking the linear stats between the price and rest variables

import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.regression.linear_model import OLS

X = X_normalized_df[['reviews_per_month','minimum_nights','number_of_reviews','availability_365','neighbourhood_group_Bronx','neighbourhood_group_Brooklyn','neighbourhood_group_Manhattan','neighbourhood_group_Queens','neighbourhood_group_Staten Island','room_type_Entire home/apt','room_type_Private room' ,'room_type_Shared room']]
# Add a constant term to the independent variables
X = sm.add_constant(X)

# Dependent variable
y = X_normalized_df['price']

# Perform the regression
model = OLS(y, X).fit()

# Print the summary results
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.093
# Model:                            OLS   Adj. R-squared:                  0.093
# Method:                 Least Squares   F-statistic:                     500.6
# Date:                Sun, 15 Jan 2023   Prob (F-statistic):               0.00
# Time:                        13:54:30   Log-Likelihood:                -66996.
# No. Observations:               48895   AIC:                         1.340e+05
# Df Residuals:                   48884   BIC:                         1.341e+05
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# 1 -  The Average Price is 152.72 and Standard Deviation of Price is 240.15 , Which shows the price are quite spreaded from mean.
#
# 2 - Brooklyn and Manhatan have more than 80% of listngs. (Brooklyn 	20104 , Manhattan 	21661)
#
# 3 - the average price for an entire home/apt is significantly higher than the average price for a private room or shared room. The maximum price for an entire home/apt and private room is also much higher than the maximum price for a shared room. This suggests that entire home/apts and private rooms are generally more expensive than shared rooms. Additionally, the range of prices for entire home/apts and private rooms is much wider than the range of prices for shared rooms, which could indicate more variability in the prices of entire home/apts and private rooms compared to shared rooms.
#
# 4 - we can see that the average price of a listing in the Bronx neighborhood is the lowest (88 ) among the five boroughs, while the average price in Manhattan is the highest (196). The max rent in Bronx is  2500 and in Staten Island  5000 rest have range till  10,000.
#
# 5 - The cheapest whole apartment is in Bronx with average price of  127.5 , private room in Staten ISland with avg price of 62.5 and shared room in Brooklyn with average price of  50.5
#
# 6 - Most reviewed properties are in Brooklyn and Manhttan.
#
# 7 - Queens have most neighbourhoods.
#
# 8 - The 'price' column has a moderate negative correlation with the 'number_of_reviews' column (-0.048). This suggests that listings with more reviews tend to have lower prices.
#
# 9 - The 'price' column has a moderate positive correlation with the 'room_type_Entire home/apt' column (0.256). This suggests that entire homes or apartments tend to have higher prices compared to private rooms or shared rooms.
#
# 10 - The 'price' column has a moderate positive correlation with the 'neighbourhood_group_Manhattan' column (0.164). This suggests that listings in Manhattan tend to have higher prices compared to listings in other neighborhoods.
#
# 11 - Higher the availabilty higher the price. we see a positive corelation between these 2.
#
# 12 -
#
# OLS Rport -
#
# The R-squared value of 0.093 indicates that the model explains about 9.3% of the variance in the price. This means that the remaining 90.7% of the variance is likely due to other factors not included in the model.
#
# None of the variables in the model are statistically significant, as indicated by the P>|t| values being greater than 0.05. This means that there is not a strong relationship between these variables and the price.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Price distribution

# Select the 'price' column
price = df['price']

# Create a histogram
plt.hist(price, bins=50, color='#008080', edgecolor='k', alpha=0.6)

# Add a title
plt.title('Distribution of Prices')

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked a histogram to show the distribution of prices because it is a useful graphical representation to visualize the frequency of different price values in the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The histogram shows that there is a relatively large number of listings with prices below $100, with a long tail of more expensive listings. There are also a few listings with very high prices, which could potentially be outliers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# The gained insights could potentially help create a positive business impact by helping to identify patterns or trends in the distribution of prices, which could inform pricing strategies or target markets for the business.

# %% [markdown]
# #### Chart - 2

# %%
# Room_type Distribution

# Extract the room_type column and calculate the value counts
room_types = df['room_type'].value_counts()

# Extract the index and values from the Series
labels = room_types.index
sizes = room_types.values

# Create the pie chart
plt.pie(sizes, labels=labels, autopct='%1.1f%%')

# Add a title
plt.title('Percentage of Listings by Room Type')

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The pie chart was chosen to display the percentage of listings by room type because it is a clear and easy-to-understand way to visualize the proportions of different categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insights found from the chart are the proportions of listings for each room type.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# The gained insights could potentially help create a positive business impact by giving an understanding of the demand for different types of listings. This information could be used to inform pricing decisions or to target marketing efforts towards specific types of listings. It could also help identify areas where there may be an opportunity to increase the supply of a certain type of listing to meet demand.

# %% [markdown]
# #### Chart - 3

# %%
# Set up a figure and subplots
fig, ax = plt.subplots(2, 2, figsize=(10, 10))

# Create histograms for the following columns:
# id, host_id, latitude, longitude, minimum_nights, number_of_reviews, 
# reviews_per_month, calculated_host_listings_count, availability_365
df.hist(column='minimum_nights', ax=ax[0,0])
df.hist(column='number_of_reviews', ax=ax[0,1])
df.hist(column='reviews_per_month', ax=ax[1,0])
df.hist(column='availability_365', ax=ax[1,1])

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The histograms were chosen to display the distribution of values for each column because they provide a visual representation of the data and allow you to see the frequency of different values in the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insights found from the chart are the distribution of values for each column. For example, the 'minimum_nights' histogram shows the number of listings that require a certain minimum number of nights to be booked, the 'number_of_reviews' histogram shows the number of listings that have a certain number of reviews, and so on.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights could potentially help create a positive business impact by giving an understanding of the characteristics of the listings in the dataset. For example, the distribution of values for the 'minimum_nights' column could inform pricing decisions or help identify patterns in the length of stays booked on the platform. The distribution of values for the 'reviews_per_month' column could help identify high-performing listings and understand what factors contribute to their success. Overall, understanding the distribution of values for different columns can help inform business decisions and strategies.

# %% [markdown]
# #### Chart - 4

# %%
import seaborn as sns

# Set up a figure and subplots
fig, ax = plt.subplots(2, 2, figsize=(10, 10))

# Create box plots for the following columns:
# minimum_nights, number_of_reviews, reviews_per_month, availability_365
sns.boxplot(data=df, x='minimum_nights', ax=ax[0,0])
sns.boxplot(data=df, x='number_of_reviews', ax=ax[0,1])
sns.boxplot(data=df, x='reviews_per_month', ax=ax[1,0])
sns.boxplot(data=df, x='availability_365', ax=ax[1,1])

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The box plots were chosen to display the distribution of values for each column because they provide a visual representation of the data and show the median, interquartile range, and outliers in the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insights found from the chart are the distribution of values for each column. For example, the 'minimum_nights' box plot shows the range of minimum nights required for different listings, the 'number_of_reviews' box plot shows the range of review counts for different listings, and so on.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# The gained insights could potentially help create a positive business impact by giving an understanding of the characteristics of the listings in the dataset. For example, the distribution of values for the 'minimum_nights' column could inform pricing decisions or help identify patterns in the length of stays booked on the platform. The distribution of values for the 'reviews_per_month' column could help identify high-performing listings and understand what factors contribute to their success. Overall, understanding the distribution of values for different columns can help inform business decisions and strategies.

# %% [markdown]
# #### Chart - 5

# %%
# Extract the 'neighbourhood' column and calculate the value counts
neighbourhood_counts = df['neighbourhood_group'].value_counts()

# Extract the index and values from the Series
labels = neighbourhood_counts.index
counts = neighbourhood_counts.values

# Create the bar chart
plt.bar(labels, counts)

# Add a title
plt.title('Number of Listings by Neighbourhood')

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The bar chart was chosen to display the counts of listings in each neighborhood because it allows you to easily compare the values and see which neighborhoods have the most listings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insight found from the chart is the number of listings in each neighborhood.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insight could potentially help create a positive business impact by giving an understanding of the distribution of listings on the platform. For example, if a particular neighborhood has a high number of listings, this could indicate a strong demand for accommodations in that area, which could inform pricing decisions or marketing strategies. On the other hand, if a neighborhood has a low number of listings, this could indicate an opportunity to increase supply in that area and potentially attract more guests. Overall, understanding the distribution of listings by neighborhood can help inform business decisions and strategies.

# %% [markdown]
# #### Chart - 6

# %%
# Set up a figure and subplots
fig, ax = plt.subplots(2, 2, figsize=(10, 10))

# Create scatter plots for the following pairs of variables:
# ('price', 'minimum_nights'), ('price', 'number_of_reviews'),
# ('price', 'reviews_per_month'), ('price', 'availability_365')
sns.scatterplot(data=df, y='price', x='minimum_nights', ax=ax[0,0])
sns.scatterplot(data=df, y='price', x='number_of_reviews', ax=ax[0,1])
sns.scatterplot(data=df, y='price', x='reviews_per_month', ax=ax[1,0])
sns.scatterplot(data=df, y='price', x='availability_365', ax=ax[1,1])

# Add a title
plt.suptitle('Scatterplots of Price and Other Variables')

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked the specific chart because it allows you to visualize the relationship between the 'price' column and several other variables. This can be helpful for understanding how these variables might influence the price of a listing.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The scatterplots allow you to see if there is any correlation between the variables - for example, do listings with higher prices tend to have higher minimum nights requirements, or vice versa? You can also see the distribution of the data for each variable, and identify any outliers or patterns.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Understanding the relationships between the variables and the factors that might influence the price of a listing could potentially help create a positive business impact. For example, if you can identify factors that are correlated with higher prices, you might be able to use this information to optimize the pricing of your own listings or to target your marketing efforts. On the other hand, if you can identify factors that are correlated with lower prices, you might be able to use this information to make your listings more competitive.

# %% [markdown]
# #### Chart - 7

# %%
# Group the data by room type and calculate the average price
grouped_data = df.groupby('room_type')['price'].mean()

# Create a list of room types and average prices
room_types = grouped_data.index
avg_prices = grouped_data.values

# Create the plot
plt.bar(room_types, avg_prices)
plt.xlabel('Room Type')
plt.ylabel('Average Price')
plt.title('Average Price by Room Type')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
# I picked the specific chart because it allows you to visualize the mean price of listings grouped by room type. This can give you a sense of how the room type of a listing might influence its price, and can help you compare the average price of different room types.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?
# The bar chart shows the mean price of each room type, which can provide insight into which types of listings tend to be more expensive. This may give a sense to the property owner about how much should they charge for their room type and make their property more competitive. Additionally, this chart can be used to compare the mean prices of different room types. For example, it can be observed that the mean price of entire home/apt is significantly higher than that of private room.

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Understanding the relationship between room type and price can have a positive business impact by helping property owners set prices that are competitive with others in the market, or target specific types of travellers who may be willing to pay more for certain room types.

# %% [markdown]
# #### Chart - 8

# %%
# Group the data by room_type and count the number of listings in each group
counts = df.groupby('room_type')['id'].count()

# Create a bar plot
fig, ax = plt.subplots()
ax.bar(counts.index, counts.values)

# Set the x-axis labels
ax.set_xticklabels(counts.index, rotation=45)

# Add a title
plt.title('Number of Listings by Room Type')

# Show the plot
plt.show()
# Out:
# C:\Users\saura\AppData\Local\Temp/ipykernel_10392/1306786331.py:9: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(counts.index, rotation=45)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked the specific chart because it allows you to visualize the number of listings for each room type. This can give you a sense of the relative popularity of different room types and can help you understand the distribution of listings across different room types.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The bar chart shows the count of each room type, which can provide insight into which types of listings are more prevalent in the data. By looking at the chart, it is easy to see the popularity of different room types among the hosts, this may guide hosts on what type of room to create and make more money.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Understanding the relative popularity of different room types can have a positive business impact by helping hosts understand the demand for different room types and adjust their strategies accordingly, for example by creating more listings of a certain room type if it is in high demand or by providing more discounts for a less popular room type to attract more guests.

# %% [markdown]
# #### Chart - 9

# %%
# Group the data by room_type and calculate the mean and standard deviation of the price for each type
price_stats = df.groupby('neighbourhood_group')['price'].agg(['mean', 'std'])

# Extract the mean and standard deviation values
means = price_stats['mean']
stds = price_stats['std']

# Set the x-axis labels
n_types = ['Brooklyn', 'Queens', 'Manhattan', 'Staten Island', 'Bronx']
x_pos = range(len(n_types))

# Create the bar plot
fig, ax = plt.subplots()
ax.bar(x_pos, means, yerr=stds, align='center', alpha=0.5, ecolor='black', capsize=10)

# Set the x-axis labels
ax.set_xticks(x_pos)
ax.set_xticklabels(n_types)

# Add a title
plt.title('Price by Neighbourhood Group')

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The bar plot is a great way to represent the mean and standard deviation of a variable for different categories. By using error bars on the bars, it also gives an indication of the variability within each group.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows the average prices and the standard deviation of the prices for different neighbourhoods group. From this graph, we can infer the neighbourhood group with the highest average prices, and the neighbourhoods group with the lowest average prices.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, this insight can help the business identify which neighbourhoods group have the highest average prices, this information can be used to identify the best location to target high-end customer and also help to understand how to set the prices for different neighbourhoods group in order to maximize revenue.

# %% [markdown]
# #### Chart - 10

# %%
# Group the data by number_of_reviews and calculate the average price
reviews_price = df.groupby('number_of_reviews')['price'].mean()

# Set the style and context of the plot
sns.set(style="darkgrid", context="notebook")

# Create the scatterplot
sns.scatterplot(x=reviews_price.index, y=reviews_price)

# Add title and labels
plt.title('Average Price vs. Number of Reviews')
plt.xlabel('Number of Reviews')
plt.ylabel('Average Price')

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked this chart because it allows us to see if there is any correlation between the number of reviews a listing has and the price of the listing.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the chart we can see that there might be a slight negative correlation between the number of reviews and the price, meaning that listings with more reviews tend to have lower prices on average. However, this correlation isn't very strong and there are many listings with high prices and low number of reviews.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insight gained from this chart can help the business by showing them that listings with more reviews tend to have lower prices. Probably the property ower give discount for better review or more people are chossing property with lower prices. However, it also suggests that high prices are not solely determined by the number of reviews. So, it also have to consider other factors too.

# %% [markdown]
# #### Chart - 11 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
# Calculate the correlation matrix
corr = df.corr()

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# Add a title
plt.title('Heatmap of Correlation Between Variables')

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The heatmap of correlation allows for an easy way to visualize and understand the correlation between different variables in the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# number_of_reviews is negatively correlated with the price which indicates as the number of reviews increases the price decreases.
#
# availability_365, which means the number of days when the property is available for booking, is positively correlated with the price, which indicates that if the property is available for more days, the price is likely to be higher.
#
# calculated_host_listings_count is positively correlated with the price, which means that as the number of listings of a host increases the price is likely to increase.
#
# However, it's important to note that correlation does not necessarily imply causation, so these insights don't necessarily mean that increasing the number of reviews or availability will lower the price, or that increasing the host's listings count will increase the price. Additionally, this correlation matrix only describes linear relationships and doesn't account for non-linear relationships or interactions between variables.

# %% [markdown]
# #### Chart - 12 - Pair Plot

# %%
# Pair Plot visualization code

# create the pair plot
sns.pairplot(data=pp, vars=df.select_dtypes(include='number'))

# show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pair plots are useful for quickly visualizing relationships between multiple variables in a dataset, which is useful for identifying patterns and outliers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We can see some slight relationships between :
#
# number_of_reviews is negatively correlated with the price which indicates as the number of reviews increases the price decreases.
#
# availability_365, which means the number of days when the property is available for booking, is positively correlated with the price, which indicates that if the property is available for more days, the price is likely to be higher.
#
# calculated_host_listings_count is positively correlated with the price, which means that as the number of listings of a host increases the price is likely to increase.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# From the data, it appears that the most important factors that affect the price of a listing are the location of the listing (specifically the neighborhood and neighborhood group), the number of reviews a listing has received, the number of reviews per month, the availability of the listing, and the room type.
#
# One strategy would be to increase the availability of the listing. This could be done by removing any restrictions on minimum nights, allowing last-minute bookings, and encouraging hosts to list their properties on the platform.
#
# The client could also focus on increasing the visibility of the listing by targeting specific neighborhoods and neighborhood groups where prices are higher. To do this, they could invest in advertising and promotions specifically for those areas.
#
# Additionally, it may be beneficial for the client to differentiate their pricing strategy for different room types as it is evident from the graph of mean price by room type that Entire home/apt is priced higher than Shared room or Private room.
#
# Lastly, the client can also consider implementing dynamic pricing based on demand and other factors to optimize their revenue.
#
# It is important to keep in mind that in order to achieve a positive business impact, the client will need to consider multiple factors that affect the price of a listing, rather than just focusing on one or two. They will also need to monitor the results of their strategies and make adjustments as necessary.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# After analyzing the data, several conclusions can be drawn:
#
# The average price of a listing is highest in Manhattan, followed by Brooklyn and Queens. This suggests that the client may want to focus their marketing efforts in these areas to attract more high-end customers.
#
# Private room and shared room have a significantly lower mean price compared to the entire home/apt room type. This means that clients should expect to have a higher return on investment if they list their entire homes or apartments on Airbnb.
#
# The number of reviews and the average price of a listing have a weak negative correlation. This suggests that listings with more reviews tend to be priced lower, which may indicate that more popular listings tend to be more budget-friendly.
#
# The number of listings and the average price of a listing also have a weak negative correlation. This suggests that as the number of listings in a neighborhood increase, the average price of listings in that neighborhood decreases.
#
# The Minimum nights and price of the listing seems to be positive correlated. It means as the minimum nights stay requirement increases, the average price of a listing also increases.
#
# The majority of listings are for entire homes or apartments, and there are relatively few private or shared rooms available. This could be an opportunity for the client to focus on listing more private or shared rooms.
#
#
# Based on these conclusions, the client may want to consider offering budget-friendly options and promote listings in areas where there are fewer listings in order to increase demand.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
